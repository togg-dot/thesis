# %%
survey = pd.read_csv("/Users/tamo/Documents/Studium/WS 20-21/Master thesis/Data/Intelliekon/survey1.csv")

# %%
descript = pd.read_csv("/Users/tamo/Documents/Studium/WS 20-21/Master thesis/Data/Intelliekon/survey1_descript.csv")

# %%
survey.head()
# Out:
#    Fall_ge             split      ort Zaehlernummer      s_dat  Enddatum  \
# 0        1  Pilotgruppe Post  Krefeld    ELON003377   4/6/2009  1/1/1970
# 1        2  Pilotgruppe Post  Krefeld    ELON003706  10/6/2009  1/1/1970
# 2        3  Pilotgruppe Post  Krefeld    ELON003684  11/8/2009  1/1/1970
# 3        4  Pilotgruppe Post  Krefeld    LW00454127   5/6/2009  1/1/1970
# 4        5  Pilotgruppe Post  Krefeld    LW00453984   7/8/2009  1/1/1970
#
#    TarifTest  Um_Auszug  LastgangValid  Befrgng2Valid  ...  \
# 0          0          0              1              1  ...
# 1          0          0              1              1  ...
# 2          0          0              1              1  ...
# 3          0          0              1              1  ...
# 4          0          0              1              0  ...
#
#                                  berufst     bildung                  hhek  \
# 0          03_Haushalt ohne Berufstätige     03_hoch         05_weiß nicht
# 1          03_Haushalt ohne Berufstätige     03_hoch  04_Angabe verweigert
# 2          03_Haushalt ohne Berufstätige   02_mittel            02_ mittel
# 3  01_Haushalt mit Ganztagsberufstätigen  01_niedrig         05_weiß nicht
# 4  01_Haushalt mit Ganztagsberufstätigen  01_niedrig            01_niedrig
#
#    hhnek_w hhnek_aeq               hhnek_aeq_k  s08_mp  CounterMain  \
# 0      1.0       0.0                       NaN      98   ELON003377
# 1      1.5       0.0                       NaN      97   ELON003706
# 2      1.5    1500.0  04_1.500 bis unter 2.000    2250   ELON003684
# 3      1.5       0.0                       NaN      98   LW00454127
# 4      2.5     300.0     01_bis unter 750 Euro     750   LW00453984
#
#    IdForTrack   IdForCons
# 0  ELON003377  ELON003377
# 1  ELON003706  ELON003706
# 2  ELON003684  ELON003684
# 3  LW00454127  LW00454127
# 4  LW00453984  LW00453984
#
# [5 rows x 225 columns]

# %%
descript.head()
# Out:
#            Name        Typ  Spaltenformat  Dezimalstellen  \
# 0       Fall_ge  Numerisch              8               2
# 1         s_dat     String             24               0
# 2       zaehler     String             20               0
# 3   Zaehler_neu     String             20               0
# 4      zaehler2     String             20               0
# 5      zaehler3     String             20               0
# 6     zaehler11  Numerisch              8               0
# 7     zaehler12  Numerisch              8               0
# 8     zaehler13  Numerisch              8               0
# 9     zaehler21  Numerisch              8               0
# 10    zaehler22  Numerisch              8               0
# 11    zaehler23  Numerisch              8               0
# 12          q01  Numerisch              8               2
# 13        q01a1  Numerisch              8               2
# 14        q01a2  Numerisch              8               2
# 15        q01a3  Numerisch              8               2
# 16        q01a4  Numerisch              8               2
# 17        q02wa  Numerisch              8               2
# 18        q02wb  Numerisch              8               2
# 19        q02pa  Numerisch              8               2
# 20        q02pb  Numerisch              8               2
# 21       q03ac1  Numerisch              8               2
# 22       q03ac2  Numerisch              8               2
# 23       q03ac3  Numerisch              8               2
# 24       q03ac4  Numerisch              8               2
# 25       q03ac5  Numerisch              8               2
# 26       q03ac7  Numerisch              8               2
# 27       q03ac8  Numerisch              8               2
# 28         q03b  Numerisch              8               2
# 29          q04  Numerisch              8               2
#
#                                        Variablenlabel  \
# 0                                          Fallnummer
# 1                                               S_DAT
# 2                                        Zählernummer
# 3                                        Zählernummer
# 4                                      Zählernummer 2
# 5                                      Zählernummer 3
# 6                                      Zählernummer 1
# 7                                      Zählernummer 2
# 8                                      Zählernummer 3
# 9                                      Zählernummer 1
# 10                                     Zählernummer 2
# 11                                     Zählernummer 3
# 12                    Anzahl der Personen im Haushalt
# 13    Anzahl der Erwachsenen ab 18 Jahren im Haushalt
# 14  Anzahl der Kinder bis einschließlich 5 Jahren ...
# 15  Anzahl der Kinder von 6 bis einschließlich 10 ...
# 16  Anzahl der Jugendlichen von 11 bis einschließl...
# 17  Kontrollfrage Pilotgruppe Web: bereits eingelo...
# 18  Kontrollfrage Pilotgruppe Web: andere Person i...
# 19  Kontrollfrage Pilotgruppe Post: bereits angesc...
# 20  Kontrollfrage Pilotgruppe Post: andere Person ...
# 21  Informationsquellen zum Stromverbrauch: damit ...
# 22  Informationsquellen zum Stromverbrauch: schaue...
# 23  Informationsquellen zum Stromverbrauch: vergle...
# 24  Informationsquellen zum Stromverbrauch: lese r...
# 25  Informationsquellen zum Stromverbrauch: führe ...
# 26  Informationsquellen zum Stromverbrauch: Angabe...
# 27  Informationsquellen zum Stromverbrauch: weiß n...
# 28  Informiertheit über Möglichkeiten des Stromspa...
# 29  Entwicklung des Haushalts-Stromverbrauches in ...
#
#                                        Wertelabels      Fehlende Werte  \
# 0                                            Keine               Keine
# 1                                            Keine               Keine
# 2                                            Keine               Keine
# 3                                            Keine               Keine
# 4                                            Keine               Keine
# 5                                            Keine               Keine
# 6                                            Keine               Keine
# 7                                            Keine               Keine
# 8                                            Keine               Keine
# 9                                            Keine               Keine
# 10                                           Keine               Keine
# 11                                           Keine               Keine
# 12                              {90,00, Filter}...        97,00, 98,00
# 13                              {90,00, Filter}...               Keine
# 14                              {90,00, Filter}...  -9999,00, -9998,00
# 15                              {90,00, Filter}...  -9999,00, -9998,00
# 16                              {90,00, Filter}...  -9999,00, -9998,00
# 17                       {1,00, ja, ich selbst}...        90,00, 91,00
# 18  {1,00, Person ist am Telefon: weiter gehts}...        90,00, 91,00
# 19                       {1,00, ja, ich selbst}...        90,00, 91,00
# 20  {1,00, Person ist am Telefon: weiter gehts}...        90,00, 91,00
# 21                      {0,00, trifft nicht zu}...        97,00, 98,00
# 22                      {0,00, trifft nicht zu}...        97,00, 98,00
# 23                      {0,00, trifft nicht zu}...        97,00, 98,00
# 24                      {0,00, trifft nicht zu}...        97,00, 98,00
# 25                      {0,00, trifft nicht zu}...        97,00, 98,00
# 26                      {0,00, trifft nicht zu}...  -9999,00, -9998,00
# 27                      {0,00, trifft nicht zu}...  -9999,00, -9998,00
# 28                             {1,00, sehr gut}...        97,00, 98,00
# 29                        {1,00, ist gestiegen}...        97,00, 98,00
#
#     Spalten   Ausrichtung Messniveau
# 0        10  Rechtsbündig   Metrisch
# 1         8   Linksbündig    Nominal
# 2        17   Linksbündig    Nominal
# 3        17   Linksbündig    Nominal
# 4        10   Linksbündig    Nominal
# 5        10   Linksbündig    Nominal
# 6        11  Rechtsbündig   Metrisch
# 7        11  Rechtsbündig   Metrisch
# 8        11  Rechtsbündig   Metrisch
# 9        13  Rechtsbündig   Metrisch
# 10        8  Rechtsbündig   Metrisch
# 11        8  Rechtsbündig   Metrisch
# 12        8  Rechtsbündig    Nominal
# 13        8  Rechtsbündig    Nominal
# 14        8  Rechtsbündig    Nominal
# 15        8  Rechtsbündig    Nominal
# 16        8  Rechtsbündig    Nominal
# 17        8  Rechtsbündig    Nominal
# 18        8  Rechtsbündig    Nominal
# 19        8  Rechtsbündig    Nominal
# 20        8  Rechtsbündig    Nominal
# 21        8  Rechtsbündig    Nominal
# 22        8  Rechtsbündig    Nominal
# 23        8  Rechtsbündig    Nominal
# 24        8  Rechtsbündig    Nominal
# 25        8  Rechtsbündig    Nominal
# 26        8  Rechtsbündig    Nominal
# 27        8  Rechtsbündig    Nominal
# 28        8  Rechtsbündig    Nominal
# 29        8  Rechtsbündig    Nominal
